# %% [markdown]
# # CE-40719: Deep Learning
# ## HW3 - CNN / CNN Case Studies / CNN Applications
# (23 points)
#
# #### Name: Sadroddin Barikbin
# #### Student No.: 98208824

# %% [markdown]
# In this assignment we go through the following topics:
# - Writing custome pytorch modules
# - Using `tensorboard` for logging and visualization
# - Data Augmentation
# - Saving / Loading Models
#
# Please Keep in mind that:
# - You can not use out-of-the-box pytorch modules (nn.Conv2d, nn.Linear, nn.BatchNorm, nn.Dropout, ...)
# - You can run this notebook on your computer. If you prefer using Google Colab you may lose some of the functionalities of `tensorboard` (like Projector). You can install `tensorboard` on your computer using package manager of your choice, and download `runs` folder from Google Colab and run it locally using `tensorboard --logdir=runs`.
# - Use the [documentation](https://pytorch.org/docs/stable/index.html).
#
# In this assignment we are going to train a convolutional neural network to classify images from [fashion-mnist](https://github.com/zalandoresearch/fashion-mnist) dataset. Fashion-mnist is a simple dataset containing 60000 training and 10000 test $28 \times 28$ grayscale images of 10 different classes. Each class corresponds to a different kind of clothing.
#
# ## 1. Setup (1.5 pts)

# %%
import torch
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms, utils
from torch.utils.data import DataLoader

# %load_ext tensorboard
# %tensorflow_version 2.x
import tensorflow as tf
import tensorboard as tb
tf.io.gfile = tb.compat.tensorflow_stub.io.gfile

from torch.utils.tensorboard import SummaryWriter

# %%
print(torch.__version__)
# Out:
# 1.4.0

# %% [markdown]
# To easily train your model on different gpu devices or your computer's cpu you can define a `torch.device` object corresponding to that device and use `.to(device)` method to easily move modules or tensors to different devices. Pytorch provides helper functions in [torch.cuda](https://pytorch.org/docs/stable/cuda.html) package.

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# create a cpu device if cuda is not available or cuda_device=None otherwise
# create a cuda:{cuda_device} device.
#################################################################################
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#################################################################################
#                                   THE END                                     #
#################################################################################
print(device)
# Out:
# cuda:0

# %% [markdown]
# Fashion-mnist dataset is available in `torchvision.datasets` package.

# %%
batch_size = 32
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# Initialize and download trainset and testset with datasets.FashionMNIST and 
# transform data into torch.Tensor. Initialize trainloader and testloader with 
# given batch_size.
#################################################################################
from torch.utils.data.sampler import SubsetRandomSampler
transform = transforms.Compose([transforms.ToTensor()])

trainset = datasets.FashionMNIST(root='./data', train=True,download=True, transform=transform)
indices=list(range(len(trainset)))
#np.random.shuffle(indices)
train_sampler = SubsetRandomSampler(indices)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, sampler=train_sampler)

testset = datasets.FashionMNIST(root='./data', train=False,download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size)

#################################################################################
#                                   THE END                                     #
#################################################################################
classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
           'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot')
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
# Processing...
# Done!

# %% [markdown]
# To get a sense of data it is always helpfull to see a few of samples. We can do this using `tensorboard`. Please read [this](https://pytorch.org/docs/stable/tensorboard.html) documentation page to get familiar with tensorboard. Run the following cell to intialize a SummaryWriter and log some of the training images to tensorboard. You can run tensorboard using `tensorboard --logdir=runs` and view images.

# %%
writer = SummaryWriter('./runs/FashionMNIST')



dataiter = iter(trainloader)
images, labels = dataiter.next()

img_grid = utils.make_grid(images[:16], nrow=4)

writer.add_image('FashionMNIST', img_grid)

# %% [markdown]
# We can also visualize data (or any representation of it) using dimmensionality reduction techniques provided by tensorboard. The following cell adds raw pixel values as embeddings to visualize data. You can see visualizations in projector tab of tensorboard after running the following cell.

# %%
def select_n_random(data, labels, n=100):
    perm = torch.randperm(len(data))
    return data[perm][:n], labels[perm][:n]

nimages, nlabels = select_n_random(trainset.data, trainset.targets)


writer.add_image('FashionMNIST', img_grid)
writer.add_embedding(nimages.view(-1, 28 * 28), 
                     metadata=[classes[label] for label in nlabels],
                     label_img=nimages.unsqueeze(1), 
                     tag='raw_pixels')
writer.flush()

# %% [markdown]
# ## 2. Modules (7 pts)

# %% [markdown]
# In this part you will define all the required modules for a convolutional model. You can only use functional package `torch.nn.functional` unless stated otherwise.
#
# ### 2.1 Convolution Module (1.5 pts)

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# define convolution parameters using nn.Parameter.
# initialize weihgt using nn.init.kaiming_uniform and bias by zeroes
# use F.conv2d in forward method.
#################################################################################
class Conv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, padding=0, bias=True):
        super(Conv2d, self).__init__()
        self.W=torch.empty(out_channels,in_channels,*kernel_size)
        nn.init.kaiming_uniform_(self.W)
        self.W=nn.Parameter(self.W)
        if bias:
            self.b=nn.Parameter(torch.zeros(out_channels))
        self.bias=bias
        self.padding=padding
        self.stride=stride

    def forward(self, x):
        out = F.conv2d(x,self.W,bias=self.b if self.bias else None,stride=self.stride,padding=self.padding)
        return out
#################################################################################
#                                   THE END                                     #
#################################################################################

# %% [markdown]
# ### 2.2 Linear (Fully-connected) Module (1.5 pts)

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# define parameters using nn.Parameter.
# initialize weihgt using nn.init.kaiming_uniform and bias by zeroes
# use F.linear in forward method.
#################################################################################
class Linear(nn.Module):
    def __init__(self, in_features, out_features, bias=True):
        super(Linear, self).__init__()
        self.W=torch.empty(out_features,in_features)
        nn.init.kaiming_uniform_(self.W)
        self.W=nn.Parameter(self.W)
        if bias:
            self.b=nn.Parameter(torch.zeros(out_features))
        self.bias=bias

    def forward(self, x):
        out = F.linear(x,self.W,bias=self.b if self.bias else None)
        return out
#################################################################################
#                                   THE END                                     #
#################################################################################

# %% [markdown]
# ### 2.3 1D Batch Normalization Module (2 pts)

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# define and intitialize running_mean and running_var by zeroes and ones
# respectively.
# define weight and bias using nn.Parameter. initialize weights to a 
# normal distribution (std=1) and bias to zero.
# use F.batch_norm in forward method.
# use self.training to differ between training and test phase.
#################################################################################
class BatchNorm(nn.Module):
    def __init__(self, num_features):
        super(BatchNorm, self).__init__()
        self.W=nn.Parameter(torch.randn(num_features))
        self.b=nn.Parameter(torch.randn(num_features))
        self.running_mean=torch.zeros(num_features).to(device)
        self.running_var=torch.ones(num_features).to(device)
    def forward(self, x):
        out = F.batch_norm(x,self.running_mean,self.running_var,weight=self.W,bias=self.b,training=self.training)
        return out
#################################################################################
#                                   THE END                                     #
#################################################################################

# %% [markdown]
# ### 2.4 2D Batch Normalization Module (2 pts)

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# define and intitialize running_mean and running_var by zeroes and ones
# respectively.
# define weight and bias using nn.Parameter. initialize weights to a
# normal distribution (std=1) and bias to zero.
# use F.batch_norm in forward method.
# use self.training to differ between training and test phase.
# more info on 2d batch normalization:
# https://stackoverflow.com/questions/38553927/batch-normalization-in-convolutional-neural-network
#################################################################################
class BatchNorm2d(nn.Module):
    def __init__(self, num_features):
        super(BatchNorm2d, self).__init__()
        self.W=nn.Parameter(torch.randn(num_features))
        self.b=nn.Parameter(torch.randn(num_features))
        self.running_mean=torch.zeros(num_features).to(device)
        self.running_var=torch.ones(num_features).to(device)
    def forward(self, x):
        out = F.batch_norm(x,self.running_mean,self.running_var,weight=self.W,bias=self.b,training=self.training)
        return out
#################################################################################
#                                   THE END                                     #
#################################################################################

# %% [markdown]
# ## 3. Model (3.5 pts)
#
# Using the modules defined in previous part define the following model:
#
# `[Conv2d(3, 3), channels=8, stride=1, padding=1] > [BatchNorm2d] > [relu]`
#
# `[Conv2d(5, 5), channels=16, stride=1, padding=0] > [BatchNorm2d] > [relu] > [max_pool2d(2, 2), stride=(2, 2), padding=0]`
#
# `[Conv2d(5, 5), channels=32, stride=1, padding=0] > [BatchNorm2d] > [relu] > [max_pool2d(2, 2), stride=(2, 2), padding=0]`
#
# `[Linear(128)] > [BatchNorm] > [relu]`
#
# `[Linear(64)] > [BatchNorm] > [relu]`        __(features)__
#
# `[Linear(10)]`

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################

class Model(nn.Module):
    def __init__(self, dropout=None):
        super(Model, self).__init__()
        self.dropout=dropout
        self.conv1=Conv2d(1,8,(3,3),padding=1)
        self.batch1=BatchNorm2d(8)
        self.conv2=Conv2d(8,16,(5,5))
        self.batch2=BatchNorm2d(16)
        self.maxpool1=nn.MaxPool2d(2)
        self.conv3=Conv2d(16,32,(5,5))
        self.batch3=BatchNorm2d(32)
        self.maxpool2=nn.MaxPool2d(2)
        self.line1=Linear(32*4*4,128)
        self.batch4=BatchNorm(128)
        self.line2=Linear(128,64)
        self.batch5=BatchNorm(64)
        self.line3=Linear(64,10)
    def forward(self, x):
        x=F.relu(self.batch1(self.conv1(x)))
        x=self.maxpool1(F.relu(self.batch2(self.conv2(x))))
        x=self.maxpool2(F.relu(self.batch3(self.conv3(x))))
        x=self.line1(torch.flatten(x,1))
        if self.dropout is not None:
            x=F.dropout(x,p=self.dropout,training=self.training)
        x=self.line2(F.relu(self.batch4(x)))
        if self.dropout is not None:
            x=F.dropout(x,p=self.dropout,training=self.training)
        features=F.relu(self.batch5(x))
        out=self.line3(features)
        return out, features
#################################################################################
#                                   THE END                                     #
#################################################################################

# %% [markdown]
# ## 4. Training the Model (5 pts)

# %%
def train(model, optimizer, trainloader, testloader, device, num_epoches, label):
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# write the main training loop procedure:
# move data to defined device
# zero_grad optimizer
# forward
# compute loss using F.cross_entropy
# backward
# step the optimizer
# accumulate running loss
#################################################################################
    model.to(device)
    for epoch in range(num_epoches):
        print('EPOCH {:2d}:'.format(epoch + 1))
        running_loss = 0.
        for i, (x, y) in enumerate(trainloader):
            inputs, labels = x.to(device), y.to(device)
            optimizer.zero_grad()
            out,_ = model(inputs)
            loss = F.cross_entropy(out, labels)
            loss.backward()
            optimizer.step()  
            running_loss += loss.item()
#################################################################################
#                                   THE END                                     #
#################################################################################
       
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# compute test loss:
# dont forget to change model mode from train to eval
# write the code in a with torch.no_grad() block to prevent computing and 
# accumulating gradients
# accumulate loss in test_loss variable
#################################################################################
            if i % 100 == 99:
                test_loss = 0.
                with torch.no_grad():
                    for data in testloader:
                        images, labels = data[0].to(device), data[1].to(device)
                        out,_ = model(images)
                        loss = F.cross_entropy(out, labels)
                        test_loss+=loss.item()
#################################################################################
#                                   THE END                                     #
#################################################################################
                writer.add_scalars('loss/'+label, 
                                   {'train': running_loss/100, 'test': test_loss/len(testloader)},
                                  global_step=epoch * len(trainloader) + i + 1)
                writer.flush()
                print('\titeration {:4d}: training_loss = {:5f}, test_loss = {:5f}'.format(i + 1, running_loss/100, test_loss/len(testloader)))
                running_loss = 0.
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# compute test accuracy:
# dont forget to change model mode from train to eval
# write the code in a with torch.no_grad() block to prevent computing and 
# accumulating gradients
# accumulate number of correct predictions in correct variable and total test
# samples in total variable
# accumulate number of classwise correct predictions in class_correct list 
# and total classwise test samples in class_total list
#################################################################################
        with torch.no_grad():
            correct = 0
            total = 0
            
            class_correct = [0.] * 10
            class_total = [0.] * 10
            for data in testloader:
                images, labels = data[0].to(device), data[1].to(device)
                out,_ = model(images)
                _, predicted = torch.max(out.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()                
                for i in range(len(labels)):
                    class_total[labels[i]]+=1
                    if predicted[i]==labels[i]:
                        class_correct[labels[i]]+=1
#################################################################################
#                                   THE END                                     #
#################################################################################
        writer.add_scalars('accuracy/'+label, {'test': correct / total},
                           global_step=(epoch + 1) * len(trainloader))
        print('test_accuracy = {:5f}'.format(correct / total))
        
        writer.add_scalars('classwise_accuracy/'+label, 
                           {classes[i]: class_correct[i]/class_total[i] for i in range(10)},
                           global_step=(epoch + 1) * len(trainloader))
        for i in range(10):
            print('  >> {:11s}: {:5f}'.format(classes[i], class_correct[i]/class_total[i]))
            
        writer.flush()
        torch.save(model.state_dict(), './model_{}.chkpt'.format(label))

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# initilize model and train for 10 epoches using Adam optimizer
#################################################################################
num_epoches = 10
model=Model()
optimizer=optim.Adam(model.parameters())

train(model, optimizer, trainloader, testloader, device, num_epoches, 'base')
#################################################################################
#                                   THE END                                     #
#################################################################################
# Out:
# EPOCH  1:
# 	iteration  100: training_loss = 1.141327, test_loss = 0.792359
# 	iteration  200: training_loss = 0.689374, test_loss = 0.645509
# 	iteration  300: training_loss = 0.594193, test_loss = 0.551898
# 	iteration  400: training_loss = 0.532206, test_loss = 0.516130
# 	iteration  500: training_loss = 0.469848, test_loss = 0.504271
# 	iteration  600: training_loss = 0.466767, test_loss = 0.467948
# 	iteration  700: training_loss = 0.425413, test_loss = 0.433405
# 	iteration  800: training_loss = 0.416112, test_loss = 0.424147
# 	iteration  900: training_loss = 0.415300, test_loss = 0.422329
# 	iteration 1000: training_loss = 0.389058, test_loss = 0.402099
# 	iteration 1100: training_loss = 0.381735, test_loss = 0.407317
# 	iteration 1200: training_loss = 0.391601, test_loss = 0.388939
# 	iteration 1300: training_loss = 0.378454, test_loss = 0.372811
# 	iteration 1400: training_loss = 0.353905, test_loss = 0.366897
# 	iteration 1500: training_loss = 0.353656, test_loss = 0.367796
# 	iteration 1600: training_loss = 0.340612, test_loss = 0.361514
# 	iteration 1700: training_loss = 0.336139, test_loss = 0.347828
# 	iteration 1800: training_loss = 0.366886, test_loss = 0.355851
# test_accuracy = 0.875500
#   >> T-shirt/top: 0.884000
#   >> Trouser    : 0.976000
#   >> Pullover   : 0.852000
#   >> Dress      : 0.872000
#   >> Coat       : 0.752000
#   >> Sandal     : 0.951000
#   >> Shirt      : 0.582000
#   >> Sneaker    : 0.972000
#   >> Bag        : 0.975000
#   >> Ankle Boot : 0.939000
# EPOCH  2:
# 	iteration  100: training_loss = 0.315332, test_loss = 0.343160
# 	iteration  200: training_loss = 0.307726, test_loss = 0.348475
# 	iteration  300: training_loss = 0.311659, test_loss = 0.340986
# 	iteration  400: training_loss = 0.315671, test_loss = 0.338647
# 	iteration  500: training_loss = 0.287406, test_loss = 0.319590
# 	iteration  600: training_loss = 0.306330, test_loss = 0.339619
# 	iteration  700: training_loss = 0.303292, test_loss = 0.323613
# 	iteration  800: training_loss = 0.312291, test_loss = 0.323678
# 	iteration  900: training_loss = 0.302524, test_loss = 0.310478
# 	iteration 1000: training_loss = 0.314104, test_loss = 0.331052
# 	iteration 1100: training_loss = 0.296146, test_loss = 0.325140
# 	iteration 1200: training_loss = 0.286544, test_loss = 0.318835
# 	iteration 1300: training_loss = 0.291062, test_loss = 0.303661
# 	iteration 1400: training_loss = 0.286693, test_loss = 0.316368
# 	iteration 1500: training_loss = 0.281909, test_loss = 0.308744
# 	iteration 1600: training_loss = 0.284129, test_loss = 0.306606
# 	iteration 1700: training_loss = 0.281539, test_loss = 0.306457
# 	iteration 1800: training_loss = 0.295329, test_loss = 0.315383
# test_accuracy = 0.891000
#   >> T-shirt/top: 0.825000
#   >> Trouser    : 0.980000
#   >> Pullover   : 0.797000
#   >> Dress      : 0.890000
#   >> Coat       : 0.887000
#   >> Sandal     : 0.978000
#   >> Shirt      : 0.655000
#   >> Sneaker    : 0.956000
#   >> Bag        : 0.978000
#   >> Ankle Boot : 0.964000
# EPOCH  3:
# 	iteration  100: training_loss = 0.257425, test_loss = 0.317333
# 	iteration  200: training_loss = 0.265973, test_loss = 0.311033
# 	iteration  300: training_loss = 0.272630, test_loss = 0.301094
# 	iteration  400: training_loss = 0.240295, test_loss = 0.298935
# 	iteration  500: training_loss = 0.264443, test_loss = 0.293933
# 	iteration  600: training_loss = 0.252254, test_loss = 0.309898
# 	iteration  700: training_loss = 0.235477, test_loss = 0.286077
# 	iteration  800: training_loss = 0.278244, test_loss = 0.300087
# 	iteration  900: training_loss = 0.253815, test_loss = 0.320774
# 	iteration 1000: training_loss = 0.268477, test_loss = 0.283386
# 	iteration 1100: training_loss = 0.259921, test_loss = 0.295589
# 	iteration 1200: training_loss = 0.265390, test_loss = 0.292363
# 	iteration 1300: training_loss = 0.258323, test_loss = 0.284019
# 	iteration 1400: training_loss = 0.260654, test_loss = 0.277858
# 	iteration 1500: training_loss = 0.259511, test_loss = 0.287393
# 	iteration 1600: training_loss = 0.275053, test_loss = 0.282109
# 	iteration 1700: training_loss = 0.246296, test_loss = 0.283051
# 	iteration 1800: training_loss = 0.264522, test_loss = 0.281619
# test_accuracy = 0.891500
#   >> T-shirt/top: 0.817000
#   >> Trouser    : 0.980000
#   >> Pullover   : 0.759000
#   >> Dress      : 0.904000
#   >> Coat       : 0.879000
#   >> Sandal     : 0.974000
#   >> Shirt      : 0.697000
#   >> Sneaker    : 0.956000
#   >> Bag        : 0.979000
#   >> Ankle Boot : 0.970000
# EPOCH  4:
# 	iteration  100: training_loss = 0.234898, test_loss = 0.285965
# 	iteration  200: training_loss = 0.218309, test_loss = 0.282454
# 	iteration  300: training_loss = 0.216571, test_loss = 0.296810
# 	iteration  400: training_loss = 0.216920, test_loss = 0.283264
# 	iteration  500: training_loss = 0.225827, test_loss = 0.292240
# 	iteration  600: training_loss = 0.224263, test_loss = 0.291942
# 	iteration  700: training_loss = 0.243678, test_loss = 0.279394
# 	iteration  800: training_loss = 0.225816, test_loss = 0.281852
# 	iteration  900: training_loss = 0.244573, test_loss = 0.290494
# 	iteration 1000: training_loss = 0.228945, test_loss = 0.292922
# 	iteration 1100: training_loss = 0.224456, test_loss = 0.273688
# 	iteration 1200: training_loss = 0.237594, test_loss = 0.280964
# 	iteration 1300: training_loss = 0.230842, test_loss = 0.278535
# 	iteration 1400: training_loss = 0.213867, test_loss = 0.279475
# 	iteration 1500: training_loss = 0.242013, test_loss = 0.281550
# 	iteration 1600: training_loss = 0.231066, test_loss = 0.276798
# 	iteration 1700: training_loss = 0.237012, test_loss = 0.275780
# 	iteration 1800: training_loss = 0.230484, test_loss = 0.289804
# test_accuracy = 0.901500
#   >> T-shirt/top: 0.872000
#   >> Trouser    : 0.983000
#   >> Pullover   : 0.798000
#   >> Dress      : 0.869000
#   >> Coat       : 0.871000
#   >> Sandal     : 0.981000
#   >> Shirt      : 0.736000
#   >> Sneaker    : 0.971000
#   >> Bag        : 0.981000
#   >> Ankle Boot : 0.953000
# EPOCH  5:
# 	iteration  100: training_loss = 0.197546, test_loss = 0.267957
# 	iteration  200: training_loss = 0.203252, test_loss = 0.277074
# 	iteration  300: training_loss = 0.203756, test_loss = 0.271782
# 	iteration  400: training_loss = 0.200003, test_loss = 0.280852
# 	iteration  500: training_loss = 0.214721, test_loss = 0.287443
# 	iteration  600: training_loss = 0.202146, test_loss = 0.275138
# 	iteration  700: training_loss = 0.204333, test_loss = 0.264193
# 	iteration  800: training_loss = 0.199844, test_loss = 0.266851
# 	iteration  900: training_loss = 0.214677, test_loss = 0.261160
# 	iteration 1000: training_loss = 0.222759, test_loss = 0.275361
# 	iteration 1100: training_loss = 0.232496, test_loss = 0.265982
# 	iteration 1200: training_loss = 0.227705, test_loss = 0.275490
# 	iteration 1300: training_loss = 0.215512, test_loss = 0.278358
# 	iteration 1400: training_loss = 0.206591, test_loss = 0.269666
# 	iteration 1500: training_loss = 0.214619, test_loss = 0.269008
# 	iteration 1600: training_loss = 0.192254, test_loss = 0.271587
# 	iteration 1700: training_loss = 0.218791, test_loss = 0.268455
# 	iteration 1800: training_loss = 0.215215, test_loss = 0.268175
# test_accuracy = 0.901500
#   >> T-shirt/top: 0.884000
#   >> Trouser    : 0.989000
#   >> Pullover   : 0.896000
#   >> Dress      : 0.883000
#   >> Coat       : 0.824000
#   >> Sandal     : 0.975000
#   >> Shirt      : 0.660000
#   >> Sneaker    : 0.971000
#   >> Bag        : 0.971000
#   >> Ankle Boot : 0.962000
# EPOCH  6:
# 	iteration  100: training_loss = 0.198427, test_loss = 0.261226
# 	iteration  200: training_loss = 0.188358, test_loss = 0.259141
# 	iteration  300: training_loss = 0.194800, test_loss = 0.279329
# 	iteration  400: training_loss = 0.194399, test_loss = 0.263237
# 	iteration  500: training_loss = 0.179208, test_loss = 0.276172
# 	iteration  600: training_loss = 0.188248, test_loss = 0.263862
# 	iteration  700: training_loss = 0.183323, test_loss = 0.276833
# 	iteration  800: training_loss = 0.208384, test_loss = 0.277650
# 	iteration  900: training_loss = 0.194877, test_loss = 0.272222
# 	iteration 1000: training_loss = 0.181316, test_loss = 0.267027
# 	iteration 1100: training_loss = 0.181623, test_loss = 0.271978
# 	iteration 1200: training_loss = 0.191135, test_loss = 0.259759
# 	iteration 1300: training_loss = 0.198164, test_loss = 0.267361
# 	iteration 1400: training_loss = 0.189505, test_loss = 0.267571
# 	iteration 1500: training_loss = 0.192341, test_loss = 0.270234
# 	iteration 1600: training_loss = 0.192414, test_loss = 0.263698
# 	iteration 1700: training_loss = 0.195656, test_loss = 0.264212
# 	iteration 1800: training_loss = 0.191331, test_loss = 0.277907
# test_accuracy = 0.904600
#   >> T-shirt/top: 0.861000
#   >> Trouser    : 0.981000
#   >> Pullover   : 0.809000
#   >> Dress      : 0.898000
#   >> Coat       : 0.906000
#   >> Sandal     : 0.988000
#   >> Shirt      : 0.702000
#   >> Sneaker    : 0.967000
#   >> Bag        : 0.984000
#   >> Ankle Boot : 0.950000
# EPOCH  7:
# 	iteration  100: training_loss = 0.159086, test_loss = 0.272829
# 	iteration  200: training_loss = 0.181065, test_loss = 0.292091
# 	iteration  300: training_loss = 0.171681, test_loss = 0.276934
# 	iteration  400: training_loss = 0.173956, test_loss = 0.282460
# 	iteration  500: training_loss = 0.184363, test_loss = 0.267065
# 	iteration  600: training_loss = 0.172950, test_loss = 0.255456
# 	iteration  700: training_loss = 0.171940, test_loss = 0.265585
# 	iteration  800: training_loss = 0.203702, test_loss = 0.276197
# 	iteration  900: training_loss = 0.189986, test_loss = 0.272754
# 	iteration 1000: training_loss = 0.189644, test_loss = 0.267178
# 	iteration 1100: training_loss = 0.172245, test_loss = 0.268201
# 	iteration 1200: training_loss = 0.161366, test_loss = 0.265164
# 	iteration 1300: training_loss = 0.170146, test_loss = 0.265031
# 	iteration 1400: training_loss = 0.186812, test_loss = 0.253090
# 	iteration 1500: training_loss = 0.173748, test_loss = 0.263216
# 	iteration 1600: training_loss = 0.175875, test_loss = 0.264000
# 	iteration 1700: training_loss = 0.193299, test_loss = 0.258311
# 	iteration 1800: training_loss = 0.176366, test_loss = 0.264644
# test_accuracy = 0.910300
#   >> T-shirt/top: 0.868000
#   >> Trouser    : 0.980000
#   >> Pullover   : 0.841000
#   >> Dress      : 0.895000
#   >> Coat       : 0.885000
#   >> Sandal     : 0.990000
#   >> Shirt      : 0.735000
#   >> Sneaker    : 0.960000
#   >> Bag        : 0.982000
#   >> Ankle Boot : 0.967000
# EPOCH  8:
# 	iteration  100: training_loss = 0.158838, test_loss = 0.274168
# 	iteration  200: training_loss = 0.150321, test_loss = 0.268471
# 	iteration  300: training_loss = 0.152336, test_loss = 0.265383
# 	iteration  400: training_loss = 0.149239, test_loss = 0.275921
# 	iteration  500: training_loss = 0.173102, test_loss = 0.269548
# 	iteration  600: training_loss = 0.176342, test_loss = 0.266732
# 	iteration  700: training_loss = 0.158741, test_loss = 0.268906
# 	iteration  800: training_loss = 0.165966, test_loss = 0.261615
# 	iteration  900: training_loss = 0.169450, test_loss = 0.269589
# 	iteration 1000: training_loss = 0.159877, test_loss = 0.279696
# 	iteration 1100: training_loss = 0.157262, test_loss = 0.272480
# 	iteration 1200: training_loss = 0.180365, test_loss = 0.273201
# 	iteration 1300: training_loss = 0.165226, test_loss = 0.270185
# 	iteration 1400: training_loss = 0.170728, test_loss = 0.272813
# 	iteration 1500: training_loss = 0.171169, test_loss = 0.272230
# 	iteration 1600: training_loss = 0.152039, test_loss = 0.274722
# 	iteration 1700: training_loss = 0.178634, test_loss = 0.265178
# 	iteration 1800: training_loss = 0.155740, test_loss = 0.261743
# test_accuracy = 0.905700
#   >> T-shirt/top: 0.833000
#   >> Trouser    : 0.987000
#   >> Pullover   : 0.910000
#   >> Dress      : 0.888000
#   >> Coat       : 0.855000
#   >> Sandal     : 0.987000
#   >> Shirt      : 0.706000
#   >> Sneaker    : 0.953000
#   >> Bag        : 0.966000
#   >> Ankle Boot : 0.972000
# EPOCH  9:
# 	iteration  100: training_loss = 0.157054, test_loss = 0.259585
# 	iteration  200: training_loss = 0.165171, test_loss = 0.277487
# 	iteration  300: training_loss = 0.147749, test_loss = 0.284132
# 	iteration  400: training_loss = 0.134320, test_loss = 0.267748
# 	iteration  500: training_loss = 0.152770, test_loss = 0.282209
# 	iteration  600: training_loss = 0.146898, test_loss = 0.270175
# 	iteration  700: training_loss = 0.143795, test_loss = 0.285567
# 	iteration  800: training_loss = 0.152284, test_loss = 0.274810
# 	iteration  900: training_loss = 0.150640, test_loss = 0.267554
# 	iteration 1000: training_loss = 0.168815, test_loss = 0.269146
# 	iteration 1100: training_loss = 0.143259, test_loss = 0.275716
# 	iteration 1200: training_loss = 0.149698, test_loss = 0.277011
# 	iteration 1300: training_loss = 0.160009, test_loss = 0.281227
# 	iteration 1400: training_loss = 0.159294, test_loss = 0.264624
# 	iteration 1500: training_loss = 0.140008, test_loss = 0.271384
# 	iteration 1600: training_loss = 0.169312, test_loss = 0.269515
# 	iteration 1700: training_loss = 0.141225, test_loss = 0.267858
# 	iteration 1800: training_loss = 0.154438, test_loss = 0.270872
# test_accuracy = 0.908600
#   >> T-shirt/top: 0.848000
#   >> Trouser    : 0.982000
#   >> Pullover   : 0.866000
#   >> Dress      : 0.939000
#   >> Coat       : 0.893000
#   >> Sandal     : 0.982000
#   >> Shirt      : 0.671000
#   >> Sneaker    : 0.959000
#   >> Bag        : 0.977000
#   >> Ankle Boot : 0.969000
# EPOCH 10:
# 	iteration  100: training_loss = 0.119758, test_loss = 0.267111
# 	iteration  200: training_loss = 0.127139, test_loss = 0.281651
# 	iteration  300: training_loss = 0.145267, test_loss = 0.271745
# 	iteration  400: training_loss = 0.138640, test_loss = 0.269603
# 	iteration  500: training_loss = 0.138388, test_loss = 0.275880
# 	iteration  600: training_loss = 0.127133, test_loss = 0.279561
# 	iteration  700: training_loss = 0.136065, test_loss = 0.285533
# 	iteration  800: training_loss = 0.144546, test_loss = 0.285102
# 	iteration  900: training_loss = 0.141311, test_loss = 0.271667
# 	iteration 1000: training_loss = 0.137794, test_loss = 0.282570
# 	iteration 1100: training_loss = 0.141573, test_loss = 0.278844
# 	iteration 1200: training_loss = 0.167425, test_loss = 0.305900
# 	iteration 1300: training_loss = 0.162555, test_loss = 0.280912
# 	iteration 1400: training_loss = 0.153468, test_loss = 0.283750
# 	iteration 1500: training_loss = 0.155680, test_loss = 0.288486
# 	iteration 1600: training_loss = 0.133692, test_loss = 0.274346
# 	iteration 1700: training_loss = 0.157112, test_loss = 0.275056
# 	iteration 1800: training_loss = 0.159962, test_loss = 0.276114
# test_accuracy = 0.909000
#   >> T-shirt/top: 0.885000
#   >> Trouser    : 0.985000
#   >> Pullover   : 0.892000
#   >> Dress      : 0.913000
#   >> Coat       : 0.853000
#   >> Sandal     : 0.979000
#   >> Shirt      : 0.671000
#   >> Sneaker    : 0.978000
#   >> Bag        : 0.981000
#   >> Ankle Boot : 0.953000

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# add model features corresponding to nimages as embedding to tensorboard
#################################################################################
writer = SummaryWriter('./runs/FashionMNIST_Embeddings')
loader=torch.utils.data.DataLoader(trainset, batch_size=64)
dataiter = iter(loader)
images, labels = dataiter.next()
images,labels=images.to(device),labels.to(device)
_,images=model(images)
writer.add_embedding(images, 
                     metadata=[classes[label] for label in labels],
                     tag='raw_pixels2')
writer.flush()
#################################################################################
#                                   THE END                                     #
#################################################################################

# %% [markdown]
# ## 5. Dropout and Data Augmentation (6 pts)
#
# Add dropout with p=0.5 to first two linear layers of the model using `F.dropout`. You can either modify the model module to take an additional parameter or write a seperate module.
#
# Data Augmentation is a strategy for increasing dataset size to prevent overfitting and better generalization. Dataset can be augmented by any transformation on data that do not change its label.
#
# Pytorch provides data augmentation transforms in `torchvision.transforms` package.

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# compose a transform using transforms.Compose that horizontally flips images 
# and use transforms.RandomResizedCrop to crop a 20 * 20 patch of the image 
# and resizing back to 28 * 28
#################################################################################
transform = transforms.Compose([transforms.RandomHorizontalFlip(),transforms.RandomResizedCrop((28,28),scale=(0.8,0.8)),transforms.ToTensor()])
trainset = datasets.FashionMNIST(root='./data', train=True,download=True, transform=transform)
testset = datasets.FashionMNIST(root='./data', train=False,download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size)

#################################################################################
#                                   THE END                                     #
#################################################################################

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()
images,labels=images.to(device),labels.to(device)
img_grid = utils.make_grid(images[:16], nrow=4)

writer.add_image('FashionMNIST/augmented', img_grid)
writer.flush()

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# initilize model and train using augmented dataset for 10 epoches
#################################################################################
model2=Model(dropout=0.5)
optimizer=optim.Adam(model2.parameters())

train(model2, optimizer, trainloader, testloader, device, 10, 'dropout')
writer.add_graph(model2, images)
#################################################################################
#                                   THE END                                     #
#################################################################################
# Out:
# EPOCH  1:
# 	iteration  100: training_loss = 2.252083, test_loss = 1.867695
# 	iteration  200: training_loss = 1.661326, test_loss = 1.491312
# 	iteration  300: training_loss = 1.406326, test_loss = 1.315079
# 	iteration  400: training_loss = 1.229969, test_loss = 1.159420
# 	iteration  500: training_loss = 1.119151, test_loss = 1.101767
# 	iteration  600: training_loss = 1.077417, test_loss = 0.996913
# 	iteration  700: training_loss = 0.975305, test_loss = 0.967309
# 	iteration  800: training_loss = 0.908823, test_loss = 0.938089
# 	iteration  900: training_loss = 0.893228, test_loss = 0.900953
# 	iteration 1000: training_loss = 0.859944, test_loss = 0.849694
# 	iteration 1100: training_loss = 0.816191, test_loss = 0.831686
# 	iteration 1200: training_loss = 0.796948, test_loss = 0.810675
# 	iteration 1300: training_loss = 0.780262, test_loss = 0.798497
# 	iteration 1400: training_loss = 0.769093, test_loss = 0.799691
# 	iteration 1500: training_loss = 0.794788, test_loss = 0.789790
# 	iteration 1600: training_loss = 0.748642, test_loss = 0.779864
# 	iteration 1700: training_loss = 0.802804, test_loss = 0.752982
# 	iteration 1800: training_loss = 0.733417, test_loss = 0.760805
# test_accuracy = 0.727000
#   >> T-shirt/top: 0.818000
#   >> Trouser    : 0.932000
#   >> Pullover   : 0.600000
#   >> Dress      : 0.696000
#   >> Coat       : 0.646000
#   >> Sandal     : 0.795000
#   >> Shirt      : 0.100000
#   >> Sneaker    : 0.859000
#   >> Bag        : 0.935000
#   >> Ankle Boot : 0.889000
# EPOCH  2:
# 	iteration  100: training_loss = 0.697517, test_loss = 0.733298
# 	iteration  200: training_loss = 0.690479, test_loss = 0.719584
# 	iteration  300: training_loss = 0.714884, test_loss = 0.710779
# 	iteration  400: training_loss = 0.717717, test_loss = 0.715195
# 	iteration  500: training_loss = 0.692953, test_loss = 0.717558
# 	iteration  600: training_loss = 0.717369, test_loss = 0.709100
# 	iteration  700: training_loss = 0.698210, test_loss = 0.700279
# 	iteration  800: training_loss = 0.683373, test_loss = 0.690854
# 	iteration  900: training_loss = 0.676924, test_loss = 0.699970
# 	iteration 1000: training_loss = 0.664291, test_loss = 0.688971
# 	iteration 1100: training_loss = 0.645743, test_loss = 0.681012
# 	iteration 1200: training_loss = 0.665441, test_loss = 0.673418
# 	iteration 1300: training_loss = 0.637013, test_loss = 0.668336
# 	iteration 1400: training_loss = 0.640422, test_loss = 0.664762
# 	iteration 1500: training_loss = 0.661944, test_loss = 0.685034
# 	iteration 1600: training_loss = 0.651102, test_loss = 0.669931
# 	iteration 1700: training_loss = 0.692384, test_loss = 0.669229
# 	iteration 1800: training_loss = 0.652182, test_loss = 0.656142
# test_accuracy = 0.761700
#   >> T-shirt/top: 0.834000
#   >> Trouser    : 0.958000
#   >> Pullover   : 0.638000
#   >> Dress      : 0.795000
#   >> Coat       : 0.672000
#   >> Sandal     : 0.821000
#   >> Shirt      : 0.147000
#   >> Sneaker    : 0.898000
#   >> Bag        : 0.933000
#   >> Ankle Boot : 0.921000
# EPOCH  3:
# 	iteration  100: training_loss = 0.617066, test_loss = 0.640913
# 	iteration  200: training_loss = 0.607721, test_loss = 0.644822
# 	iteration  300: training_loss = 0.632183, test_loss = 0.645434
# 	iteration  400: training_loss = 0.619202, test_loss = 0.635700
# 	iteration  500: training_loss = 0.632238, test_loss = 0.640316
# 	iteration  600: training_loss = 0.648081, test_loss = 0.642077
# 	iteration  700: training_loss = 0.607497, test_loss = 0.637497
# 	iteration  800: training_loss = 0.628987, test_loss = 0.634065
# 	iteration  900: training_loss = 0.606004, test_loss = 0.637757
# 	iteration 1000: training_loss = 0.617860, test_loss = 0.628020
# 	iteration 1100: training_loss = 0.593466, test_loss = 0.629794
# 	iteration 1200: training_loss = 0.597724, test_loss = 0.631180
# 	iteration 1300: training_loss = 0.611126, test_loss = 0.612724
# 	iteration 1400: training_loss = 0.606788, test_loss = 0.611534
# 	iteration 1500: training_loss = 0.627786, test_loss = 0.613463
# 	iteration 1600: training_loss = 0.582275, test_loss = 0.607853
# 	iteration 1700: training_loss = 0.615722, test_loss = 0.618749
# 	iteration 1800: training_loss = 0.593397, test_loss = 0.612979
# test_accuracy = 0.783100
#   >> T-shirt/top: 0.848000
#   >> Trouser    : 0.961000
#   >> Pullover   : 0.641000
#   >> Dress      : 0.814000
#   >> Coat       : 0.708000
#   >> Sandal     : 0.878000
#   >> Shirt      : 0.207000
#   >> Sneaker    : 0.896000
#   >> Bag        : 0.947000
#   >> Ankle Boot : 0.931000
# EPOCH  4:
# 	iteration  100: training_loss = 0.574849, test_loss = 0.602197
# 	iteration  200: training_loss = 0.559572, test_loss = 0.599614
# 	iteration  300: training_loss = 0.583489, test_loss = 0.598089
# 	iteration  400: training_loss = 0.577165, test_loss = 0.592636
# 	iteration  500: training_loss = 0.593625, test_loss = 0.600277
# 	iteration  600: training_loss = 0.601129, test_loss = 0.600233
# 	iteration  700: training_loss = 0.582224, test_loss = 0.597678
# 	iteration  800: training_loss = 0.582472, test_loss = 0.589875
# 	iteration  900: training_loss = 0.590178, test_loss = 0.604211
# 	iteration 1000: training_loss = 0.553171, test_loss = 0.589738
# 	iteration 1100: training_loss = 0.573146, test_loss = 0.589142
# 	iteration 1200: training_loss = 0.565930, test_loss = 0.574044
# 	iteration 1300: training_loss = 0.561105, test_loss = 0.572828
# 	iteration 1400: training_loss = 0.569677, test_loss = 0.570198
# 	iteration 1500: training_loss = 0.575580, test_loss = 0.572570
# 	iteration 1600: training_loss = 0.545117, test_loss = 0.570385
# 	iteration 1700: training_loss = 0.582664, test_loss = 0.576076
# 	iteration 1800: training_loss = 0.542865, test_loss = 0.582655
# test_accuracy = 0.790300
#   >> T-shirt/top: 0.844000
#   >> Trouser    : 0.948000
#   >> Pullover   : 0.661000
#   >> Dress      : 0.837000
#   >> Coat       : 0.710000
#   >> Sandal     : 0.881000
#   >> Shirt      : 0.236000
#   >> Sneaker    : 0.904000
#   >> Bag        : 0.939000
#   >> Ankle Boot : 0.943000
# EPOCH  5:
# 	iteration  100: training_loss = 0.530974, test_loss = 0.570369
# 	iteration  200: training_loss = 0.532275, test_loss = 0.560430
# 	iteration  300: training_loss = 0.542617, test_loss = 0.556535
# 	iteration  400: training_loss = 0.546600, test_loss = 0.564817
# 	iteration  500: training_loss = 0.555351, test_loss = 0.558234
# 	iteration  600: training_loss = 0.579965, test_loss = 0.558764
# 	iteration  700: training_loss = 0.526066, test_loss = 0.564441
# 	iteration  800: training_loss = 0.522521, test_loss = 0.561583
# 	iteration  900: training_loss = 0.548535, test_loss = 0.576441
# 	iteration 1000: training_loss = 0.546587, test_loss = 0.553405
# 	iteration 1100: training_loss = 0.519682, test_loss = 0.553381
# 	iteration 1200: training_loss = 0.560059, test_loss = 0.540323
# 	iteration 1300: training_loss = 0.541951, test_loss = 0.554977
# 	iteration 1400: training_loss = 0.537331, test_loss = 0.556360
# 	iteration 1500: training_loss = 0.559068, test_loss = 0.533222
# 	iteration 1600: training_loss = 0.520130, test_loss = 0.542915
# 	iteration 1700: training_loss = 0.530623, test_loss = 0.537439
# 	iteration 1800: training_loss = 0.530739, test_loss = 0.561321
# test_accuracy = 0.805000
#   >> T-shirt/top: 0.841000
#   >> Trouser    : 0.950000
#   >> Pullover   : 0.693000
#   >> Dress      : 0.831000
#   >> Coat       : 0.750000
#   >> Sandal     : 0.878000
#   >> Shirt      : 0.303000
#   >> Sneaker    : 0.911000
#   >> Bag        : 0.962000
#   >> Ankle Boot : 0.931000
# EPOCH  6:
# 	iteration  100: training_loss = 0.513194, test_loss = 0.542505
# 	iteration  200: training_loss = 0.505442, test_loss = 0.540939
# 	iteration  300: training_loss = 0.535547, test_loss = 0.534829
# 	iteration  400: training_loss = 0.515109, test_loss = 0.537742
# 	iteration  500: training_loss = 0.511637, test_loss = 0.538673
# 	iteration  600: training_loss = 0.534837, test_loss = 0.531726
# 	iteration  700: training_loss = 0.504732, test_loss = 0.531303
# 	iteration  800: training_loss = 0.522289, test_loss = 0.549329
# 	iteration  900: training_loss = 0.523801, test_loss = 0.528447
# 	iteration 1000: training_loss = 0.527515, test_loss = 0.527292
# 	iteration 1100: training_loss = 0.504538, test_loss = 0.538671
# 	iteration 1200: training_loss = 0.507063, test_loss = 0.525036
# 	iteration 1300: training_loss = 0.493367, test_loss = 0.536321
# 	iteration 1400: training_loss = 0.496617, test_loss = 0.516241
# 	iteration 1500: training_loss = 0.530738, test_loss = 0.532692
# 	iteration 1600: training_loss = 0.506490, test_loss = 0.530260
# 	iteration 1700: training_loss = 0.527742, test_loss = 0.517228
# 	iteration 1800: training_loss = 0.490118, test_loss = 0.513835
# test_accuracy = 0.809600
#   >> T-shirt/top: 0.855000
#   >> Trouser    : 0.955000
#   >> Pullover   : 0.707000
#   >> Dress      : 0.821000
#   >> Coat       : 0.761000
#   >> Sandal     : 0.902000
#   >> Shirt      : 0.318000
#   >> Sneaker    : 0.903000
#   >> Bag        : 0.950000
#   >> Ankle Boot : 0.924000
# EPOCH  7:
# 	iteration  100: training_loss = 0.484129, test_loss = 0.520781
# 	iteration  200: training_loss = 0.470711, test_loss = 0.528091
# 	iteration  300: training_loss = 0.524059, test_loss = 0.513042
# 	iteration  400: training_loss = 0.507526, test_loss = 0.520018
# 	iteration  500: training_loss = 0.485095, test_loss = 0.516820
# 	iteration  600: training_loss = 0.512440, test_loss = 0.514471
# 	iteration  700: training_loss = 0.514443, test_loss = 0.521168
# 	iteration  800: training_loss = 0.497655, test_loss = 0.519694
# 	iteration  900: training_loss = 0.504736, test_loss = 0.539633
# 	iteration 1000: training_loss = 0.501986, test_loss = 0.516313
# 	iteration 1100: training_loss = 0.485451, test_loss = 0.514571
# 	iteration 1200: training_loss = 0.469583, test_loss = 0.491108
# 	iteration 1300: training_loss = 0.478879, test_loss = 0.508360
# 	iteration 1400: training_loss = 0.476737, test_loss = 0.523924
# 	iteration 1500: training_loss = 0.517448, test_loss = 0.502907
# 	iteration 1600: training_loss = 0.482247, test_loss = 0.510470
# 	iteration 1700: training_loss = 0.504494, test_loss = 0.516234
# 	iteration 1800: training_loss = 0.487730, test_loss = 0.517483
# test_accuracy = 0.819400
#   >> T-shirt/top: 0.875000
#   >> Trouser    : 0.964000
#   >> Pullover   : 0.729000
#   >> Dress      : 0.808000
#   >> Coat       : 0.781000
#   >> Sandal     : 0.889000
#   >> Shirt      : 0.336000
#   >> Sneaker    : 0.937000
#   >> Bag        : 0.955000
#   >> Ankle Boot : 0.920000
# EPOCH  8:
# 	iteration  100: training_loss = 0.471181, test_loss = 0.502330
# 	iteration  200: training_loss = 0.461806, test_loss = 0.498966
# 	iteration  300: training_loss = 0.488339, test_loss = 0.498696
# 	iteration  400: training_loss = 0.479073, test_loss = 0.503214
# 	iteration  500: training_loss = 0.461828, test_loss = 0.502665
# 	iteration  600: training_loss = 0.514277, test_loss = 0.510743
# 	iteration  700: training_loss = 0.470044, test_loss = 0.502035
# 	iteration  800: training_loss = 0.478791, test_loss = 0.497167
# 	iteration  900: training_loss = 0.486602, test_loss = 0.498165
# 	iteration 1000: training_loss = 0.487311, test_loss = 0.484760
# 	iteration 1100: training_loss = 0.461485, test_loss = 0.488909
# 	iteration 1200: training_loss = 0.474886, test_loss = 0.497489
# 	iteration 1300: training_loss = 0.479317, test_loss = 0.491330
# 	iteration 1400: training_loss = 0.476756, test_loss = 0.479131
# 	iteration 1500: training_loss = 0.493607, test_loss = 0.492873
# 	iteration 1600: training_loss = 0.447324, test_loss = 0.484587
# 	iteration 1700: training_loss = 0.486189, test_loss = 0.478293
# 	iteration 1800: training_loss = 0.461744, test_loss = 0.500912
# test_accuracy = 0.822200
#   >> T-shirt/top: 0.858000
#   >> Trouser    : 0.956000
#   >> Pullover   : 0.763000
#   >> Dress      : 0.815000
#   >> Coat       : 0.767000
#   >> Sandal     : 0.898000
#   >> Shirt      : 0.343000
#   >> Sneaker    : 0.916000
#   >> Bag        : 0.956000
#   >> Ankle Boot : 0.950000
# EPOCH  9:
# 	iteration  100: training_loss = 0.457156, test_loss = 0.488338
# 	iteration  200: training_loss = 0.441928, test_loss = 0.479088
# 	iteration  300: training_loss = 0.497613, test_loss = 0.482642
# 	iteration  400: training_loss = 0.460347, test_loss = 0.502304
# 	iteration  500: training_loss = 0.463060, test_loss = 0.481191
# 	iteration  600: training_loss = 0.495330, test_loss = 0.481055
# 	iteration  700: training_loss = 0.472908, test_loss = 0.477997
# 	iteration  800: training_loss = 0.468313, test_loss = 0.503049
# 	iteration  900: training_loss = 0.469929, test_loss = 0.487257
# 	iteration 1000: training_loss = 0.464027, test_loss = 0.489372
# 	iteration 1100: training_loss = 0.441279, test_loss = 0.485391
# 	iteration 1200: training_loss = 0.458128, test_loss = 0.480615
# 	iteration 1300: training_loss = 0.459136, test_loss = 0.489393
# 	iteration 1400: training_loss = 0.453984, test_loss = 0.465254
# 	iteration 1500: training_loss = 0.503248, test_loss = 0.478160
# 	iteration 1600: training_loss = 0.449815, test_loss = 0.477248
# 	iteration 1700: training_loss = 0.491612, test_loss = 0.484073
# 	iteration 1800: training_loss = 0.440778, test_loss = 0.480737
# test_accuracy = 0.830400
#   >> T-shirt/top: 0.851000
#   >> Trouser    : 0.960000
#   >> Pullover   : 0.765000
#   >> Dress      : 0.871000
#   >> Coat       : 0.699000
#   >> Sandal     : 0.889000
#   >> Shirt      : 0.447000
#   >> Sneaker    : 0.924000
#   >> Bag        : 0.956000
#   >> Ankle Boot : 0.942000
# EPOCH 10:
# 	iteration  100: training_loss = 0.445627, test_loss = 0.483931
# 	iteration  200: training_loss = 0.452082, test_loss = 0.472721
# 	iteration  300: training_loss = 0.466096, test_loss = 0.471360
# 	iteration  400: training_loss = 0.455591, test_loss = 0.465704
# 	iteration  500: training_loss = 0.460143, test_loss = 0.479953
# 	iteration  600: training_loss = 0.488532, test_loss = 0.480068
# 	iteration  700: training_loss = 0.462327, test_loss = 0.475407
# 	iteration  800: training_loss = 0.447523, test_loss = 0.486050
# 	iteration  900: training_loss = 0.483366, test_loss = 0.477749
# 	iteration 1000: training_loss = 0.470582, test_loss = 0.482392
# 	iteration 1100: training_loss = 0.435592, test_loss = 0.470115
# 	iteration 1200: training_loss = 0.441185, test_loss = 0.475304
# 	iteration 1300: training_loss = 0.451511, test_loss = 0.475509
# 	iteration 1400: training_loss = 0.442122, test_loss = 0.459152
# 	iteration 1500: training_loss = 0.467368, test_loss = 0.481530
# 	iteration 1600: training_loss = 0.443263, test_loss = 0.471257
# 	iteration 1700: training_loss = 0.485228, test_loss = 0.458045
# 	iteration 1800: training_loss = 0.450244, test_loss = 0.478844
# test_accuracy = 0.833100
#   >> T-shirt/top: 0.830000
#   >> Trouser    : 0.964000
#   >> Pullover   : 0.698000
#   >> Dress      : 0.855000
#   >> Coat       : 0.814000
#   >> Sandal     : 0.922000
#   >> Shirt      : 0.436000
#   >> Sneaker    : 0.899000
#   >> Bag        : 0.965000
#   >> Ankle Boot : 0.948000

# %%
#################################################################################
#                          COMPLETE THE FOLLOWING SECTION                       #
#################################################################################
# add model features corresponding to nimages as embedding to tensorboard
#################################################################################
writer = SummaryWriter('./runs/FashionMNIST_Embeddings')
loader=torch.utils.data.DataLoader(trainset, batch_size=64)
dataiter = iter(loader)
images, labels = dataiter.next()
images,labels=images.to(device),labels.to(device)
_,images=model2(images)
writer.add_embedding(images, 
                     metadata=[classes[label] for label in labels],
                     tag='raw_pixels')
writer.flush()
writer.close()
###############################passpasspasspass##################################################
#                                   THE END                                     #
#################################################################################
